# %% [markdown]
# # Context

# %% [markdown]
# In this project, we are going to use k-Nearest_Neighbour or knn, a classification algorithm to detect whether a transaction is a Fraud case or a legit one.

# %% [markdown]
# # About the data

# %% [markdown]
# The first thing we must do is gather a basic sense of our data. Remember, except for the transaction and amount we dont know what the other columns are (due to privacy reasons). The only thing we know, is that those columns that are unknown have been scaled already.
#
# Summary:
# The transaction amount is relatively small. The mean of all the mounts made is approximately USD 88.
# There are no "Null" values, so we don't have to work on ways to replace values.
# Most of the transactions were Non-Fraud (99.83%) of the time, while Fraud transactions occurs (017%) of the time in the dataframe.

# %% [markdown]
# # Preprocessing

# %% [markdown]
# PCA Transformation and Scaling has already been applied to the DataSet as said in the Description of the provider.

# %% [markdown]
# # Code

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline

# %%
df = pd.read_csv("G:/Data_Sets/creditcard.csv", index_col = 0)
df.head()
# Out:
#             V1        V2        V3        V4        V5        V6        V7  \
# Time
# 0.0  -1.359807 -0.072781  2.536347  1.378155 -0.338321  0.462388  0.239599
# 0.0   1.191857  0.266151  0.166480  0.448154  0.060018 -0.082361 -0.078803
# 1.0  -1.358354 -1.340163  1.773209  0.379780 -0.503198  1.800499  0.791461
# 1.0  -0.966272 -0.185226  1.792993 -0.863291 -0.010309  1.247203  0.237609
# 2.0  -1.158233  0.877737  1.548718  0.403034 -0.407193  0.095921  0.592941
#
#             V8        V9       V10  ...       V21       V22       V23  \
# Time                                ...
# 0.0   0.098698  0.363787  0.090794  ... -0.018307  0.277838 -0.110474
# 0.0   0.085102 -0.255425 -0.166974  ... -0.225775 -0.638672  0.101288
# 1.0   0.247676 -1.514654  0.207643  ...  0.247998  0.771679  0.909412
# 1.0   0.377436 -1.387024 -0.054952  ... -0.108300  0.005274 -0.190321
# 2.0  -0.270533  0.817739  0.753074  ... -0.009431  0.798278 -0.137458
#
# ...

# %%
df.describe()
# Out:
#                  V1            V2            V3            V4            V5  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   3.919560e-15  5.688174e-16 -8.769071e-15  2.782312e-15 -1.552563e-15
# std    1.958696e+00  1.651309e+00  1.516255e+00  1.415869e+00  1.380247e+00
# min   -5.640751e+01 -7.271573e+01 -4.832559e+01 -5.683171e+00 -1.137433e+02
# 25%   -9.203734e-01 -5.985499e-01 -8.903648e-01 -8.486401e-01 -6.915971e-01
# 50%    1.810880e-02  6.548556e-02  1.798463e-01 -1.984653e-02 -5.433583e-02
# 75%    1.315642e+00  8.037239e-01  1.027196e+00  7.433413e-01  6.119264e-01
# max    2.454930e+00  2.205773e+01  9.382558e+00  1.687534e+01  3.480167e+01
#
#                  V6            V7            V8            V9           V10  \
# count  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05  2.848070e+05
# mean   2.010663e-15 -1.694249e-15 -1.927028e-16 -3.137024e-15  1.768627e-15
# ...

# %%
df.dtypes
# Out:
# V1        float64
# V2        float64
# V3        float64
# V4        float64
# V5        float64
# V6        float64
# V7        float64
# V8        float64
# V9        float64
# V10       float64
# V11       float64
# V12       float64
# V13       float64
# V14       float64
# V15       float64
# V16       float64
# V17       float64
# V18       float64
# V19       float64
# V20       float64
# V21       float64
# V22       float64
# V23       float64
# V24       float64
# V25       float64
# V26       float64
# V27       float64
# V28       float64
# Amount    float64
# Class       int64
# dtype: object

# %%
count_fraud = 0
for i in df.Class:
    if(i==1):
        count_fraud=count_fraud+1
print("There are %d number of fraud cases" %count_fraud)
count_legit = len(df.Class)-count_fraud
print("There are %d number of legit cases" %count_legit)
# Out:
# There are 492 number of fraud cases
# There are 284315 number of legit cases

# %%
from sklearn.model_selection import train_test_split
x = df.drop(["Amount","Class"],axis = 1)
y = df["Class"]

x_train,x_test,y_train,y_test = train_test_split(x,y,test_size = 0.25, random_state = 43)


from sklearn.neighbors import KNeighborsClassifier

# %%
error = []
for i in range(1,60):
    knn = KNeighborsClassifier(n_neighbors = i)
    knn.fit(x_train,y_train)
    pred  = knn.predict(x_test)
    error.append(np.mean(pred != y_test))

# %%
plt.figure(figsize = (10,6))
plt.plot(range(1,60),error, color = "b",marker="o",markerfacecolor = "r", markersize = 10)
plt.title("Error vs K Value")
plt.xlabel("K_Neighbours")
plt.ylabel("Error")
# Out:
# Text(0, 0.5, 'Error')

# %%
knn_new = KNeighborsClassifier(n_neighbors=4)
knn_new.fit(x_train,y_train)
# Out:
# KNeighborsClassifier(n_neighbors=4)

# %%
pred_new = knn_new.predict(x_test)

# %%
from sklearn.metrics import classification_report,confusion_matrix

# %%
print(confusion_matrix(y_test,pred_new))
# Out:
# [[71066     9]
#  [   31    96]]

# %%
print(classification_report(y_test,pred_new))
# Out:
#               precision    recall  f1-score   support
#
#            0       1.00      1.00      1.00     71075
#            1       0.91      0.76      0.83       127
#
#     accuracy                           1.00     71202
#    macro avg       0.96      0.88      0.91     71202
# weighted avg       1.00      1.00      1.00     71202
